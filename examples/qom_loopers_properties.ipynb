# %% [markdown]
# # Property Looper Example
#
# > Usage demo of `qom.loopers.properties` module.
#
# ## Dependencies

# %%
# dev dependencies
from qom.loopers import properties
# Out:
# MainProcess              INFO    2020-09-27 23:08:51.328: (qom.ui.log) -------------------Logger Initialized-------------------

# %% [markdown]
# ## System Model

# %%
# demo class
class Model:
    """Class containing the model.

    Attributes
    ----------
        name : str
            Name of the model
        
        code : str
            Short code for the model

        params : dict
            Base parameters for the model.
    """
    
    # demo attributes
    name = 'My Model Class'
    code = 'mmc'
    params = {
        'x': 2.0
    }

    # demo property function
    def square(self):
        """Function to obtain square value.
            
        Returns
        -------
            y : float
                Square of the parameter.
        """

        return self.params['x']**2

# %% [markdown]
# ## Basic Usage

# %%
# data for modules
script_data = {
    # property parameters
    'prop_params': {
        # function in the library
        'func': 'properties_1D',
        # function in the model
        'code': 'square',
        # name of the function
        'name': 'Square',
        # variable in the x-axis
        'X': {
            'var': 'x',
            'min': -5,
            'max': 5,
            'steps': 101
        }
    },
    # option to show plot
    'plot': True,
    # plot parameters
    'plot_params': {
        # plot title
        'title': 'Square Function',
        # axis labels
        'x_label': '$x$',
        'y_label': '$x^{2}$',
        # line plot
        'type': 'line'
    }
}

# calculate properties
Values, Thres, Axes = properties.calculate(Model(), script_data)
# Out:
# MainProcess              INFO    2020-09-27 23:08:52.307: (qom.loopers.properties) Initializing Square calculation...
# MainProcess              INFO    2020-09-27 23:08:52.315: (qom.loopers.properties) ----------------Property Values Obtained----------------
# MainProcess              INFO    2020-09-27 23:08:52.660: (qom.loopers.properties) Threshold values: {'x': -5.0}

# %% [markdown]
# ## Calculating Gradients

# %%
# data for modules
script_data = {
    # property parameters
    'prop_params': {
        # function in the library
        'func': 'properties_grad_1D',
        # function in the model
        'code': 'square',
        # name of the function
        'name': 'Square',
        # variable in the x-axis
        'X': {
            'var': 'x',
            'min': -5,
            'max': 5,
            'steps': 101
        }
    },
    # option to show plot
    'plot': True,
    # plot parameters
    'plot_params': {
        # plot title
        'title': 'Square Function',
        # axis labels
        'x_label': '$x$',
        'y_label': '$x^{2}$',
        # line plot
        'type': 'scatter'
    }
}

# calculate properties
Values, Thres, Axes = properties.calculate(Model(), script_data)
# Out:
# MainProcess              INFO    2020-09-27 23:08:52.674: (qom.loopers.properties) Initializing Square calculation...
# MainProcess              INFO    2020-09-27 23:08:52.682: (qom.loopers.properties) ----------------Property Values Obtained----------------
# MainProcess              INFO    2020-09-27 23:08:52.683: (qom.loopers.properties) Threshold values: {'x': -5.0}
# MainProcess              INFO    2020-09-27 23:08:52.702: (qom.loopers.properties) Initializing Square gradient calculation...
# MainProcess              INFO    2020-09-27 23:08:52.708: (qom.loopers.properties) ----------------Gradient Values Obtained----------------
# MainProcess              INFO    2020-09-27 23:08:52.916: (qom.loopers.properties) Threshold values: {'x': 5.0}
